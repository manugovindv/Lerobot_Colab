# %% [markdown]
# <a href="https://colab.research.google.com/github/manugovindv/Lerobot_Colab/blob/master/lerobot_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-venv python3.10-dev -y

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
#!echo 1 | sudo update-alternatives --config python3
# !sudo update-alternatives --set python3 /usr/bin/python3.10

# %%
# !python3 --version

# %%
# !sudo apt-get install -y cmake build-essential python3-dev pkg-config libavformat-dev libavcodec-dev libavdevice-dev libavutil-dev libswscale-dev libswresample-dev libavfilter-dev ffmpeg

# %%
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10

# %%
# !git clone https://github.com/ZhangZhiyuanZhang/lerobot-equibim.git
# %cd lerobot-equibim
# !python3.10 -m pip install -e .
# !python3.10 -m pip install -e ".[feetech]"

# %%
import wandb
wandb.login()

# %%
# !lerobot-train \
    --dataset.repo_id=<username>/record-test \
    --dataset.root="/content/drive/MyDrive/path/to/dataset/<username>/record-test" \
    --policy.type=act \
    --policy.push_to_hub=false \
    --output_dir="/content/drive/MyDrive/Lero/outputs/train_act_final" \
    --job_name=act_100_episodes_test \
    --policy.device=cuda \
    --wandb.enable=true \
    --wandb.project=Lerobot_Project_test \
    --steps=20000 \
    --batch_size=8
